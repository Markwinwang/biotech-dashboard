# %% [markdown]
# # 血液肿瘤 MoA 全景分析与 BD 战略建议
# ## Hematologic Malignancies Mechanism of Action Landscape & BD Strategy
#
# ---
#
# **Prepared for:** Novartis 全球业务拓展部 (BD&L)
# **Date:** January 2026
# **Scope:** MDS, AML, MF, PV/ET, ALL, DLBCL, PTCL, MM
#
# ---
#
# *Based on 2023-2025 Clinical Data (ASH, EHA, ASCO) & 2026 Market Outlook*

# %% [markdown]
# # Executive Summary
#
# ## 核心结论：诺华需在三大战略方向发力，以巩固血液肿瘤领先地位
#
# | 战略优先级 | 核心行动 | 预期价值 |
# |-----------|---------|----------|
# | **Priority 1** | 引进 **Menin 抑制剂** 强势进入 AML 核心市场 | 峰值销售 >$1.5B |
# | **Priority 2** | 锁定 **GPRC5D 靶点** 保持 MM 赛道竞争力 | 差异化非BCMA资产 |
# | **Priority 3** | 通过 **JAK1i (PTCL)** 实现细分市场垄断 | 低风险 Niche Buster |
# | **Priority 4** | 关注 **Next-Gen CD47** 填补 IO 空白 | 长期战略布局 |

# %%
# Setup for visualizations
import pandas as pd
import numpy as np

# Try to import visualization libraries
try:
    import matplotlib.pyplot as plt
    import matplotlib.patches as mpatches
    MATPLOTLIB_AVAILABLE = True
except ImportError:
    MATPLOTLIB_AVAILABLE = False
    print("matplotlib not available, skipping visualizations")

# Set style for McKinsey-like clean visuals
if MATPLOTLIB_AVAILABLE:
    plt.style.use('seaborn-v0_8-whitegrid')
    plt.rcParams['font.family'] = 'sans-serif'
    plt.rcParams['font.size'] = 12
    plt.rcParams['axes.titlesize'] = 14
    plt.rcParams['axes.labelsize'] = 12

# %% [markdown]
# # Strategic Logic Flow
#
# ```
# ┌─────────────────────────────────────────────────────────────────────┐
# │  利用 Pelabresib 巩固 MF/MDS  →  Menin 进入 AML  →  PTCL 细分垄断  │
# │         (已有优势)                (核心突破)         (差异化布局)    │
# └─────────────────────────────────────────────────────────────────────┘
# ```
#
# **Key Insight:** 三步走战略实现血液肿瘤全领域布局

# %%
# Market Attractiveness vs Competition Matrix
if MATPLOTLIB_AVAILABLE:
    fig, ax = plt.subplots(figsize=(12, 8))

    # Define positions (competition intensity, market attractiveness)
    opportunities = {
        'PTCL/JAK1i': (0.2, 0.85, 'Blue Ocean'),
        'AML/Menin': (0.8, 0.9, 'Must Win'),
        'MDS/Telomerase': (0.3, 0.5, 'Differentiation'),
        'MM/BCMA': (0.9, 0.4, 'Red Ocean'),
        'MF/BET': (0.4, 0.7, 'Novartis Lead'),
        'GPRC5D': (0.6, 0.75, 'Strategic'),
    }

    colors = {
        'Blue Ocean': '#2E86AB',
        'Must Win': '#E94F37',
        'Differentiation': '#F39C12',
        'Red Ocean': '#95A5A6',
        'Novartis Lead': '#27AE60',
        'Strategic': '#8E44AD',
    }

    for name, (x, y, category) in opportunities.items():
        ax.scatter(x, y, s=800, c=colors[category], alpha=0.7, edgecolors='black', linewidth=2)
        ax.annotate(name, (x, y), fontsize=10, ha='center', va='center', fontweight='bold')

    # Quadrant lines
    ax.axhline(y=0.5, color='gray', linestyle='--', alpha=0.5)
    ax.axvline(x=0.5, color='gray', linestyle='--', alpha=0.5)

    # Labels
    ax.set_xlabel('Competition Intensity →', fontsize=14, fontweight='bold')
    ax.set_ylabel('Market Attractiveness →', fontsize=14, fontweight='bold')
    ax.set_title('Market Landscape: Attractiveness vs. Competition Matrix', fontsize=16, fontweight='bold', pad=20)

    # Quadrant labels
    ax.text(0.25, 0.95, 'BLUE OCEAN\n(蓝海机会)', ha='center', fontsize=11, style='italic', color='#2E86AB')
    ax.text(0.75, 0.95, 'MUST WIN\n(必争之地)', ha='center', fontsize=11, style='italic', color='#E94F37')
    ax.text(0.25, 0.1, 'NICHE', ha='center', fontsize=11, style='italic', color='gray')
    ax.text(0.75, 0.1, 'RED OCEAN\n(红海竞争)', ha='center', fontsize=11, style='italic', color='#95A5A6')

    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)

    # Legend
    legend_elements = [mpatches.Patch(facecolor=c, label=l, alpha=0.7) for l, c in colors.items()]
    ax.legend(handles=legend_elements, loc='lower right', fontsize=9)

    plt.tight_layout()
    plt.show()
else:
    print("Market Matrix Visualization (requires matplotlib)")
    print("="*60)
    print("HIGH ATTRACTIVENESS / LOW COMPETITION: PTCL/JAK1i (Blue Ocean)")
    print("HIGH ATTRACTIVENESS / HIGH COMPETITION: AML/Menin (Must Win)")
    print("MEDIUM / LOW: MDS/Telomerase, MF/BET (Novartis Lead)")
    print("LOW / HIGH: MM/BCMA (Red Ocean)")

# %% [markdown]
# # Novartis Current Position by Indication
#
# | 适应症 | Top MoA | 领跑者 | 诺华现状 |
# |-------|---------|-------|----------|
# | MDS | Telomerase, BCL-2, TGF-β | Geron, AbbVie, BMS | ⚠️ 缺乏核心资产 |
# | AML | Menin, FLT3, CD123 双抗 | Syndax, Kura, Daiichi | ⚠️ 仅 Rydapt |
# | MF | BET, BCL-xL, ACVR1 | **Novartis**, GSK | ✅ Pelabresib 领先 |
# | MM | GPRC5D, CELMoD, BCL-2 | J&J, BMS, AbbVie | ❌ 严重落后 |
# | DLBCL | CD20双抗, BTK降解剂 | Roche, AbbVie | ⚠️ Kymriah 受挑战 |
# | PTCL | EZH1/2, JAK1 | Daiichi, Jackpharm | ❌ 空白 |

# %% [markdown]
# # MDS Deep Dive
#
# ## MDS 领域：Telomerase 与 BCL-2 成为突破性治疗两大支柱
#
# ### Top 3 Most Promising MoAs
#
# | Rank | MoA | Drug | Stage | Key Value |
# |------|-----|------|-------|----------|
# | 1️⃣ | **Telomerase Inhibition** | Imetelstat | Approved | 8周TI率~40%，低危MDS突破 |
# | 2️⃣ | **BCL-2 Inhibition** | Venetoclax+HMA | Phase 3 | 高危MDS OS改善 |
# | 3️⃣ | **TGF-β Ligand Trap** | Luspatercept/Ker-050 | Approved/Ph2-3 | 贫血改善，Ker-050更广谱 |

# %% [markdown]
# ## MDS Watch List
#
# | 靶点 | 机制/价值 |
# |-----|----------|
# | IRAK4 抑制剂 | 针对剪接因子突变 (SF3B1) |
# | TIM-3 抗体 (Sabatolimab) | 特定亚组潜力 (Novartis asset) |
# | CD47/SIRPα Next-gen | 更安全的 "Don't Eat Me" 阻断 |
# | 口服 Decitabine/Cedazuridine | 便利性改进 |
# | Menin 抑制剂 | NPM1m/KMT2Ar MDS亚群 |
# | RARA 激动剂 (Tamibarotene) | RARA过表达亚群 |
# | NLRP3 抑制剂 | 炎症驱动型MDS |

# %% [markdown]
# # AML Deep Dive ⭐ HIGHEST PRIORITY
#
# ## Menin 抑制剂将重塑 30-40% 患者的治疗格局 — 诺华必须入场
#
# ### Top 3 Most Promising MoAs
#
# | Rank | MoA | Drug | Stage | Key Data |
# |------|-----|------|-------|----------|
# | 1️⃣ | **Menin-KMT2A Inhibition** | Revumenib, Ziftomenib | NDA/Pivotal Ph2 | R/R AML CR/CRh >30% |
# | 2️⃣ | **Next-Gen FLT3** | Quizartinib, Tuspetinib | Approved/Ph3 | 克服1/2代耐药 |
# | 3️⃣ | **CD123 x CD3 双抗** | Flotetuzumab, Vibecotamab | Phase 1/2 | 广泛CD123表达 |
#
# ---
#
# ⚠️ **战略警示：** Menin 抑制剂是确定的下一个 Blockbuster
# 诺华若不入场，将在 AML 核心市场边缘化

# %% [markdown]
# # MF Deep Dive ✅ NOVARTIS LEAD
#
# ## 诺华凭借 Pelabresib 占据领先地位 — 需巩固并扩大优势
#
# ### Top 3 Most Promising MoAs
#
# | Rank | MoA | Drug | Stage | Key Value |
# |------|-----|------|-------|----------|
# | 1️⃣ | **BET Inhibition** | Pelabresib | NDA | SVR35+TSS50优于Rux单药，生物学修正潜力 |
# | 2️⃣ | **BCL-xL Inhibition** | Navitoclax | Phase 3 | 联合JAKi深度凋亡 |
# | 3️⃣ | **ACVR1/JAK1/JAK2** | Momelotinib | Approved | 降低Hepcidin改善贫血 |
#
# ---
#
# ✅ **战略优势：** Novartis (via MorphoSys) 拥有该领域最强资产
# 应作为 MF 领域持续扩张的基石

# %% [markdown]
# # MM Deep Dive ⚠️ GAP ALERT
#
# ## BCMA 后时代已开启，GPRC5D 成为下一个核心战场
#
# ### Top 3 Most Promising MoAs
#
# | Rank | MoA | Drug | Stage | Key Value |
# |------|-----|------|-------|----------|
# | 1️⃣ | **GPRC5D Targeted** | Talquetamab/CAR-T | Approved/Ph2 | BCMA独立，失败后有效 |
# | 2️⃣ | **CELMoDs** | Iberdomide, Mezigdomide | Phase 3 | 克服IMiD耐药，全口服 |
# | 3️⃣ | **BCL-2 [t(11;14)]** | Venetoclax | Phase 3 | 首个生物标志物驱动MM疗法 |
#
# ---
#
# ⚠️ **战略警示：** 诺华在 MM 领域严重落后 J&J 和 BMS
# 必须拥有非 BCMA 靶点资产才能留在赛道

# %% [markdown]
# # Lymphoma Deep Dive
#
# ## DLBCL 双抗格局已定，PTCL 存在差异化蓝海机会
#
# ### DLBCL (弥漫大B) — 红海市场
#
# | MoA | 药物 | 战略意义 |
# |-----|------|----------|
# | CD20 x CD3 双抗 | Epcoritamab, Glofitamab | 挑战 CAR-T，进入 1L |
# | BTK 降解剂 | NX-2127 | 克服 BTKi 耐药 |
# | ADC | Polatuzumab | 1L Pola-R-CHP 已确立 |
#
# ### PTCL (外周T) — ⭐ 蓝海机会
#
# | MoA | 药物 | 关键亮点 |
# |-----|------|----------|
# | EZH1/2 Dual | Valemetostat | ATLL/PTCL 单药活性惊人 |
# | **JAK1 高选择** | **Golidocitinib** | R/R PTCL 数据优异 |
# | PI3K δ/γ | — | 安全性待优化 |

# %% [markdown]
# # China Strategic Considerations
#
# ## 中国市场呈现独特机会结构，本土创新资产具有全球输出潜力
#
# ### 流行病学与监管特点
#
# | 维度 | 中国特色 |
# |-----|----------|
# | 患者基数 | AML/MDS 庞大 |
# | 独特亚型 | NK/T 细胞淋巴瘤 (NKTCL) 发病率显著高于西方 |
# | 监管态度 | First-in-class 开放，Me-too 收紧 |
# | 上市路径 | 附条件批准为主要路径 |
#
# ### 支付与准入
#
# | 品类 | 医保可及性 | 定价策略 |
# |-----|-----------|----------|
# | CAR-T | ❌ 难入医保 | 商保/惠民保 |
# | 双抗 | ✅ 支付意愿高 | 年费 ≤30万 RMB |
# | ADC | ✅ 支付意愿高 | 年费 ≤30万 RMB |

# %% [markdown]
# ## China Local Innovation Advantages
#
# ### 独特 MoA 机会领域
#
# | 领域 | 优势 | 代表企业 |
# |-----|------|----------|
# | **PTCL/NKTCL** | MNC开发动力不足，Global License-out潜力 | Jackpharm, Dizal |
# | **CAR-T** | 全球最活跃，成本极具竞争力，双靶点创新活跃 | Legend, Gracell |
# | **Bispecifics** | 全球进度领先，巨大BD合作空间 | 康方, 信达 |
#
# ---
#
# **建议：** 重点关注本土 Biotech 在双抗和亚洲特有亚型 (NKTCL) 的创新资产

# %%
# BD Priority Targets Visualization
if MATPLOTLIB_AVAILABLE:
    fig, ax = plt.subplots(figsize=(14, 8))

    priorities = [
        ('P1: Menin Inhibitor\n(AML/ALL)', 0.95, 0.9, 1500, '#E94F37'),
        ('P2: GPRC5D Bispecific\n(MM)', 0.7, 0.75, 800, '#8E44AD'),
        ('P3: JAK1i Golidocitinib\n(PTCL)', 0.85, 0.6, 500, '#2E86AB'),
        ('P4: Next-Gen CD47\n(MDS/AML)', 0.5, 0.45, 400, '#F39C12'),
    ]

    for name, strategic, success, size, color in priorities:
        ax.scatter(strategic, success, s=size*2, c=color, alpha=0.6, edgecolors='black', linewidth=2)
        ax.annotate(name, (strategic, success), fontsize=10, ha='center', va='center', fontweight='bold')

    ax.set_xlabel('Strategic Fit →', fontsize=14, fontweight='bold')
    ax.set_ylabel('Success Probability →', fontsize=14, fontweight='bold')
    ax.set_title('BD Priority Targets: Strategic Fit vs. Success Probability\n(Bubble size = Peak Sales Potential)', fontsize=16, fontweight='bold', pad=20)

    ax.set_xlim(0.3, 1.1)
    ax.set_ylim(0.3, 1.0)

    # Legend for bubble size
    ax.text(0.35, 0.95, 'Bubble Size = Peak Sales ($M)', fontsize=10, style='italic')

    plt.tight_layout()
    plt.show()
else:
    print("BD Priority Targets")
    print("="*60)
    print("P1: Menin Inhibitor - Highest Strategic Fit, Peak Sales >$1.5B")
    print("P2: GPRC5D Bispecific - High Strategic Fit, Peak Sales ~$800M")
    print("P3: JAK1i (PTCL) - High Success Prob, Peak Sales ~$500M")
    print("P4: Next-Gen CD47 - Medium Priority, Peak Sales ~$400M")

# %% [markdown]
# # Priority 1: Menin Inhibitor ⭐⭐⭐
#
# ## HIGHEST PRIORITY — AML/ALL
#
# | 评估维度 | 详情 |
# |---------|------|
# | **目标资产** | Revumenib (Syndax) 或 Ziftomenib (Kura) |
# | **适应症** | R/R AML (NPM1m, KMT2Ar) |
# | **阶段** | NDA Submitted / Pivotal Phase 2 |
#
# ### Strategic Rationale
#
# | Factor | Assessment |
# |--------|------------|
# | Portfolio Fit | ✅ 完美补充 AML 不足 (目前仅 Rydapt/FLT3) |
# | Market Moat | ✅ 确定的下一个 Blockbuster，覆盖 30-40% AML |
# | Commercial | ✅ 峰值销售 >$1.0-1.5B，移植桥接价值极高 |
# | Feasibility | ✅ Syndax 可能寻求 ex-US 合作或整体收购 |

# %% [markdown]
# # Priority 2: GPRC5D Bispecific
#
# ## STRATEGIC PRIORITY — Multiple Myeloma
#
# | 评估维度 | 详情 |
# |---------|------|
# | **首选** | Talquetamab (J&J) — unlikely to divest |
# | **替代方向** | 差异化 GPRC5D 双抗 (更低味觉毒性) |
# | **备选资产** | ABBV-383 (BCMA) 或 HPN217 (Harpoon/Merck) |
# | **推荐关注** | 中国 Biotech 早期管线 (InnoCare, RemeGen) |
#
# ### Strategic Rationale
#
# | Factor | Assessment |
# |--------|------------|
# | Gap Analysis | ⚠️ 诺华在 MM 严重落后 J&J/BMS |
# | Strategic Need | ✅ 必须拥有非 BCMA 靶点资产 |
# | Differentiation | 寻找安全性更优的差异化资产 |

# %% [markdown]
# # Priority 3: JAK1 Inhibitor (PTCL)
#
# ## NICHE BUSTER — China/Global Play
#
# | 评估维度 | 详情 |
# |---------|------|
# | **目标资产** | Golidocitinib (Dizal / Jackpharm) |
# | **适应症** | R/R PTCL |
# | **阶段** | NDA (China), Phase 2 (Global) |
# | **关键数据** | ORR ~44%, CR ~24% 在末线 PTCL，持久性好 |
#
# ### Strategic Rationale
#
# | Factor | Assessment |
# |--------|------------|
# | Unmet Need | ✅ PTCL 缺乏标准治疗 |
# | Differentiation | ✅ 全球首个口服高选择性 JAK1 for PTCL |
# | Risk Profile | ✅ 低风险、高成功率 "Niche Buster" |
# | Synergy | ✅ 利用诺华全球血液肿瘤商业化网络 |
# | **Valuation** | 中等 (~$300-500M upfront + milestones) |

# %% [markdown]
# # Priority 4: Next-Gen CD47
#
# ## LONG-TERM STRATEGIC — MDS/AML IO
#
# | 评估维度 | 详情 |
# |---------|------|
# | **目标资产** | Evorpacept (ALX Oncology) 或 Immune Oncia assets |
# | **适应症** | MDS / AML |
# | **定位** | 长期战略布局 |
#
# ### Strategic Rationale
#
# | Factor | Assessment |
# |--------|------------|
# | Market Opportunity | Magrolimab (Gilead) 失败后，赛道重新开放 |
# | Differentiation | Evorpacept 独特 Fc 设计，红细胞毒性更低 |
# | Combination | 可与 Venetoclax 联用 |
# | Risk Level | ⚠️ 中高风险，需验证安全性改善 |

# %% [markdown]
# # Strategic Roadmap
#
# ## 诺华血液肿瘤 BD 战略：三步走路线图
#
# ```
# ┌─────────────────────────────────────────────────────────────────────┐
# │   Phase 1: 巩固优势        Phase 2: 核心突破        Phase 3: 差异化布局 │
# │   ─────────────────        ─────────────────        ───────────────── │
# │   利用 Pelabresib          引进 Menin 抑制剂        PTCL 细分市场垄断  │
# │   巩固 MF/MDS 领域         强势进入 AML 核心市场    (JAK1i)           │
# │                                                     下一代 MM 靶点    │
# │                            核心优先级                (GPRC5D)         │
# └─────────────────────────────────────────────────────────────────────┘
# ```
#
# ### 避免策略
#
# - ❌ 避开拥挤的 CD20 双抗红海 (DLBCL)
# - ❌ 不追逐 BCMA 赛道后发资产
# - ❌ 不进入无差异化的 Me-too 开发

# %% [markdown]
# # Key Action Items
#
# ## 关键行动项
#
# | 优先级 | 行动 | 时间框架 | 负责方 |
# |-------|------|---------|--------|
# | 🔴 P1 | 启动 Syndax/Kura 尽职调查 (Menin) | Q1 2026 | BD |
# | 🔴 P1 | 完成 Menin 资产估值与交易结构设计 | Q2 2026 | Corp Dev |
# | 🟡 P2 | 筛选 GPRC5D 差异化资产 | Q1-Q2 2026 | Search & Eval |
# | 🟡 P2 | 与 Dizal/Jackpharm 接触 (JAK1i) | Q1 2026 | BD China |
# | 🟢 P3 | 监测 Next-Gen CD47 临床进展 | Ongoing | Scientific Affairs |
#
# ### China-Specific Actions
#
# - ✅ 重点关注本土 Biotech 双抗资产
# - ✅ 挖掘亚洲特有亚型 (NKTCL) 创新资产
# - ✅ 利用中国 CAR-T 创新生态系统

# %% [markdown]
# # Appendix
#
# ## 数据来源
#
# - **临床数据:** ASH, EHA, ASCO 年会数据 (2023-2025)
# - **市场展望:** 2026年预测
# - **竞争情报:** 公开披露信息、ClinicalTrials.gov、公司财报
#
# ## 适应症缩写
#
# | 缩写 | 全称 |
# |-----|------|
# | MDS | Myelodysplastic Syndromes 骨髓增生异常综合征 |
# | AML | Acute Myeloid Leukemia 急性髓系白血病 |
# | MF | Myelofibrosis 骨髓纤维化 |
# | MM | Multiple Myeloma 多发性骨髓瘤 |
# | DLBCL | Diffuse Large B-Cell Lymphoma 弥漫大B细胞淋巴瘤 |
# | PTCL | Peripheral T-Cell Lymphoma 外周T细胞淋巴瘤 |
#
# ---
#
# **Document Version:** 1.0 | **Classification:** Confidential
